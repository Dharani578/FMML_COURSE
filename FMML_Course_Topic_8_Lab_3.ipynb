# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharani578/FMML_COURSE/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 08:07:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   189MB/s    in 0.4s
#
# 2024-03-28 08:07:12 (189 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22386  1605.04435v1  This volume is a collection of contributions f...  stat
# 21864   1402.1412v2  In this tutorial we explain the inference proc...  stat
# 36341   1212.0582v1  Probabilistic programming is related to a comp...    cs
# 23442   1204.6563v2  Model based methods to marker-free motion capt...    cs
# 28569  1707.01083v2  We introduce an extremely computation-efficien...    cs
# ...             ...                                                ...   ...
# 12509  1802.06287v1  Vehicle recognition and classification have br...  stat
# 21879   1403.6499v2  In this paper, we consider low rank matrix est...  stat
# 16768  1705.10415v1  Authorship attribution is a natural language p...    cs
# 22449  1607.03792v1  We study the density estimation problem with o...  stat
# 6884   1707.01543v2  Early stopping of iterative algorithms is a wi...  stat
#
#                                                    title  year  \
# 22386  Proceedings of the 5th Workshop on Machine Lea...  2016
# 21864  Variational Inference in Sparse Gaussian Proce...  2014
# 36341  Compositional Stochastic Modeling and Probabil...  2012
# 23442  Parametric annealing: a stochastic search meth...  2012
# 28569  ShuffleNet: An Extremely Efficient Convolution...  2017
# ...                                                  ...   ...
# 12509  Unsupervised vehicle recognition using increme...  2018
# 21879  Optimal Schatten-q and Ky-Fan-k Norm Rate of L...  2014
# 16768                      On the "Calligraphy" of Books  2017
# 22449    Kernel Density Estimation for Dynamical Systems  2016
# 6884   Early stopping for kernel boosting algorithms:...  2017
#
#                                                 keywords
# 22386  [collection, contributions, interpretation, ne...
# 21864  [inference, procedures, developed, regression,...
# 36341  [probabilistic, programming, compositional, st...
# 23442  [computational, unattractive, optimization, te...
# 28569  [introduce, extremely, computation, efficient,...
# ...                                                  ...
# 12509  [recognition, classification, applications, ma...
# 21879  [estimation, estimator, measurements, measurem...
# 16768  [authorship, attribution, processing, consider...
# 22449  [estimation, observations, generated, dynamica...
# 6884   [iterative, algorithms, regularization, statis...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22386    [collection, contributions, interpretation, ne...
# 21864    [inference, procedures, developed, regression,...
# 36341    [probabilistic, programming, compositional, st...
# 23442    [computational, unattractive, optimization, te...
# 28569    [introduce, extremely, computation, efficient,...
#                                ...
# 4863     [quantization, requirements, perspective, appl...
# 32638    [regression, technique, simultaneously, discov...
# 16114    [coordinated, languages, knowledge, discovery,...
# 39250    [facilitate, operation, highlighted, potential...
# 17781    [summarization, extensively, traditional, appr...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8884 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5dae6e7a-385e-4334-9a1e-029e76fa8c12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dae6e7a-385e-4334-9a1e-029e76fa8c12")) {                    Plotly.newPlot(                        "5dae6e7a-385e-4334-9a1e-029e76fa8c12",                        [{"x":["applications","individual","neuroimaging","practical","approaches","developed","measurement","challenges","measuring","neuroscience","dimensional","detection","traditional","diagnosis","questions","cognitive","collection","interaction","community","processing","environments","directions","relationships","multivariate","proceedings","contributions","statistical","behavioral","important","univariate","prognosis","techniques","paradigms","prominent","methodology","dominated","psychology","naturalistic","information","interpretation","conference","isolation","increasingly","variational","understanding","references","inference","procedures","appropriate","collecting","equations","processes","published","different","derivation","implemented","accompany","regression","secondary","substantial","therefore","knowledge","derivations","implementation","parametrisation","stochastic","operators","simulation","systematically","programming","evolution","consequences","continuous","probabilistic","potentially","reduction","proceeding","semantics","computational","foundation","compositional","available","algorithms","switching","sensitivity","algorithm","significant","resources","parameters","annealing","optimization","diffusion","demonstrated","parametric","parameter","improvement","qualitative","dimensionality","tolerates","articulated","introduce","experiments","demonstrate","extremely","pointwise","computation","specially","maintaining","computing","convolutional","architecture","performance","comparable","convolution","efficient","operations","classification","structures","robustness","uncertain","introducing","construct","effective","significantly","checkerboard","incorporate","upsampling","delivered","encourage","mechanism","artifacts","uncertainties","contribution","reformulated","favorably","deconvolution","extensive","generalize","controlled","accurately","transmitted","simulates","synthetic","components","polarization","irradiance","extensively","generation","separating","reflected","generated","scenarios","successfully","including","transmission","reflections","reflection","assumptions","statistically","necessary","transformation","independent","observations","separation","minimizes","alternatives","recovering","controllable","alternative","canonical","magnitude","properties","computationally","approximation","correlation","component","searching","approximations","combinations","demanding","independence","complexity","optimizing","randomized","decomposition","calculating","generalized","excitement","stimulate","classifier","observers","otherwise","according","extracted","obviously","accumulated","direction","highlight","belonging","triggered"],"y":[448,113,3,139,446,185,30,116,36,11,175,369,191,54,57,44,68,91,63,269,78,41,70,19,11,53,167,13,350,6,5,376,8,17,65,6,11,3,715,74,16,14,57,58,144,6,207,29,82,16,22,100,38,756,14,91,3,128,2,50,128,343,4,130,0,123,52,72,18,117,53,11,100,153,46,99,2,91,297,29,29,286,594,9,32,844,239,62,265,10,318,26,109,35,140,144,55,60,1,11,310,608,570,57,6,159,12,27,126,393,233,911,111,48,412,63,523,140,111,32,47,89,249,251,2,63,6,5,13,105,23,11,65,5,24,10,162,58,26,63,6,2,137,93,2,2,38,142,9,10,167,86,94,251,10,5,11,73,21,72,70,136,79,24,12,26,20,5,100,27,50,213,70,124,76,108,22,40,33,5,28,220,35,28,61,18,68,2,2,136,5,18,94,121,8,8,57,28,15,6],"type":"bar"},{"x":["applications","individual","neuroimaging","practical","approaches","developed","meas ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7858333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Simple</span> <span style=''>Yet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Rank</span> <span style=''>One</span> <span style=''>Update</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.641025641025641);'>Covariance</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adaptation</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximated</span> <span style=''>rank</span> <span style=''>one</span> <span style=''>update</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.641025641025641);'>covariance</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adaptation</span> <span style='background-color:rgba(0, 255, 0, 0.3766233766233766);'>evolution</span> <span style=''>strategy</span> <span style=''>(CMA</span> <span style=''>ES)</span> <span style=''>It</span> <span style=''>makes</span> <span style=''>use</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3766233766233766);'>evolution</span> <span style=''>paths</span> <span style=''>as</span> <span style=''>simple</span> <span style=''>as</span> <span style=''>that</span> <span style=''>of</span> <span style=''>CMA</span> <span style=''>ES</span> <span style=''>while</span> <span style=''>avoiding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviors</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experimentally</span> <span style=''>study</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.35135135135135137);'>performances</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperforms</span> <span style=''>or</span> <span style=''>performs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitively</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Cholesky</span> <span style=''>CMA</span> <span style=''>ES</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>back</span> <span style=''>door</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalize</span> <span style=''>Pearls</span> <span style=''>back</span> <span style=''>door</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>for</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style=''>graphs</span> <span style=''>(DAGs)</span> <span style=''>to</span> <span style=''>more</span> <span style=''>general</span> <span style=''>types</span> <span style=''>of</span> <span style=''>graphs</span> <span style=''>that</span> <span style=''>describe</span> <span style=''>Markov</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>DAGs</span> <span style=''>andor</span> <span style=''>allow</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrarily</span> <span style=''>many</span> <span style=''>hidden</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>We</span> <span style=''>also</span> <span style=''>give</span> <span style=''>easily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>checkable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>criteria</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfies</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>back</span> <span style=''>door</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considering</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intervention</span> <span style=''>and</span> <span style=''>a</span> <span style=''>single</span> <span style=''>outcome</span> <span style=''>variable</span> <span style=''>Moreover</span> <span style=''>if</span> <span style=''>such</span> <span style=''>a</span> <span style=''>set</span> <span style=''>exists</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>an</span> <span style=''>explicit</span> <span style=''>set</span> <span style=''>that</span> <span style=''>fulfills</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>the</span> <span style=''>results</span> <span style=''>in</span> <span style=''>several</span> <span style=''>examples</span> <span style=''>R</span> <span style=''>code</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>the</span> <span style=''>R</span> <span style=''>package</span> <span style=''>pcalg</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>Exchangeable</span> <span style=''>Variable</span> <span style=''>Models</span> <br/><br/><span style=''>A</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.36666666666666664);'>variables</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>exchangeable</span> <span style=''>if</span> <span style=''>its</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3904761904761905);'>invariant</span> <span style=''>under</span> <span style=''>variable</span> <span style='background-color:rgba(255, 0, 0, 0.37499999999999994);'>permutations</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>exchangeable</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>(EVMs)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>whose</span> <span style=''>basic</span> <span style=''>building</span> <span style=''>blocks</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>exchangeable</span> <span style='background-color:rgba(0, 255, 0, 0.45985401459854025);'>sequences</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>exchangeable</span> <span style='background-color:rgba(0, 255, 0, 0.45985401459854025);'>sequences</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>EVMs</span> <span style=''>is</span> <span style=''>optimal</span> <span style=''>under</span> <span style=''>zero</span> <span style=''>one</span> <span style=''>loss</span> <span style=''>for</span> <span style=''>a</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>parity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>threshold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>strictly</span> <span style=''>subsumes</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(255, 0, 0, 0.3170731707317073);'>independence</span> <span style=''>based</span> <span style=''>model</span> <span style=''>families</span> <span style='background-color:rgba(0, 255, 0, 0.3170731707317073);'>Extensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>show</span> <span style=''>that</span> <span style=''>EVMs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>such</span> <span style=''>as</span> <span style=''>SVMs</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>models< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Determining</span> <span style=''>the</span> <span style=''>Number</span> <span style=''>of</span> <span style=''>Clusters</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consensus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>We</span> <span style=''>use</span> <span style=''>a</span> <span style=''>cluster</span> <span style=''>ensemble</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>k</span> <span style=''>in</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style=''>data</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>formed</span> <span style=''>from</span> <span style=''>the</span> <span style=''>ensemble</span> <span style=''>using</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>several</span> <span style=''>values</span> <span style=''>for</span> <span style=''>k</span> <span style=''>A</span> <span style=''>random</span> <span style=''>walk</span> <span style=''>is</span> <span style=''>induced</span> <span style=''>on</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvalues</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>matrix</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>For</span> <span style=''>noisy</span> <span style=''>or</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>to</span> <span style=''>refine</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style=''>matrix</span> <span style=''>in</span> <span style=''>way</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encourages</span> <span style=''>a</span> <span style=''>block</span> <span style=''>diagonal</span> <span style=''>form</span> <span style=''>It</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style=''>matrix</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>superior</span> <span style=''>to</span> <span style=''>existing</span> <span style='backgrou ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08381294964028776)
# 	knowledge (0.12338129496402878)
# 	representation (0.12733812949640289)
# 	segmentation (0.07446043165467627)
# 	experimental (0.1485611510791367)
# 	information (0.25719424460431656)
# 	detection (0.1327338129496403)
# 	different (0.2719424460431655)
# 	recognition (0.13345323741007195)
# 	convolutional (0.14136690647482014)
#
# Some Statistics words are:
# 	algorithm (0.39455445544554457)
# 	stochastic (0.13762376237623763)
# 	variables (0.14207920792079207)
# 	theoretical (0.15247524752475247)
# 	statistical (0.1603960396039604)
# 	distribution (0.1792079207920792)
# 	estimation (0.1787128712871287)
# 	dimensional (0.18366336633663366)
# 	inference (0.2004950495049505)
# 	regression (0.1801980198019802)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f252898e-fc88-459f-aa56-68e392429dd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f252898e-fc88-459f-aa56-68e392429dd9")) {                    Plotly.newPlot(                        "f252898e-fc88-459f-aa56-68e392429dd9",                        [{"x":["applications","individual","neuroimaging","practical","approaches","developed","measurement","challenges","measuring","neuroscience","dimensional","detection","traditional","diagnosis","questions","cognitive","collection","interaction","community","processing","environments","directions","relationships","multivariate","proceedings","contributions","statistical","behavioral","important","univariate","prognosis","techniques","paradigms","prominent","methodology","dominated","psychology","naturalistic","information","interpretation","conference","isolation","increasingly","variational","understanding","references","inference","procedures","appropriate","collecting","equations","processes","published","different","derivation","implemented","accompany","regression","secondary","substantial","therefore","knowledge","derivations","implementation","parametrisation","stochastic","operators","simulation","systematically","programming","evolution","consequences","continuous","probabilistic","potentially","reduction","proceeding","semantics","computational","foundation","compositional","available","algorithms","switching","sensitivity","algorithm","significant","resources","parameters","annealing","optimization","diffusion","demonstrated","parametric","parameter","improvement","qualitative","dimensionality","tolerates","articulated","introduce","experiments","demonstrate","extremely","pointwise","computation","specially","maintaining","computing","convolutional","architecture","performance","comparable","convolution","efficient","operations","classification","structures","robustness","uncertain","introducing","construct","effective","significantly","checkerboard","incorporate","upsampling","delivered","encourage","mechanism","artifacts","uncertainties","contribution","reformulated","favorably","deconvolution","extensive","generalize","controlled","accurately","transmitted","simulates","synthetic","components","polarization","irradiance","extensively","generation","separating","reflected","generated","scenarios","successfully","including","transmission","reflections","reflection","assumptions","statistically","necessary","transformation","independent","observations","separation","minimizes","alternatives","recovering","controllable","alternative","canonical","magnitude","properties","computationally","approximation","correlation","component","searching","approximations","combinations","demanding","independence","complexity","optimizing","randomized","decomposition","calculating","generalized","excitement","stimulate","classifier","observers","otherwise","according","extracted","obviously","accumulated","direction","highlight","belonging","triggered","perception","expensive","indicating","experimental","attending","attention","recordings","discriminate","likelihood","automatically","effectiveness","highlights","designing","automatize","inferring","guarantees","estimation","simulations","guarantee","nonparametric","minimization","predictors","prediction","comparing","stability","identification","predictor","clustering","euclidean","precision","similarity","divergence","correctness","producing","overlapping","closeness","overlapped","regardless","reconstruction","laplacian","determination","implementing","eigenvectors","visualization","assumption","approximated","distribution","eigenvalue","theoretical","achieving","eigenspace","filtering","variables","increasing","invariant","obser ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parametrisation
# 	gracefully
# 	imbalances
# 	unobservable
# 	ellipsoids
# 	autoencoding
# 	procrustes
# 	reconstructive
# 	convenience
# 	periodicity
# 	extrapolation
# 	statistician
# 	thurstone
# 	sparsities
# 	minimizers
# 	subgaussian
# 	substantiate
# 	integrators
# 	interventional
# 	commonplace
# Some words which never appear in Statistics papers:
# 	articulated
# 	checkerboard
# 	upsampling
# 	transmitted
# 	polarization
# 	reflections
# 	reflection
# 	stimulate
# 	observers
# 	triggered
# 	attending
# 	binocular
# 	pioneering
# 	cryptanalysis
# 	pinpointing
# 	publishing
# 	imagination
# 	deliberately
# 	extractors
# 	resiliency

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0898529230008654e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7433333333333333
